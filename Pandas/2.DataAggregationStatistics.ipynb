# %% [markdown]
# # Data Aggregation and Statistics in Python
#
# Data aggregation and statistics in Python uses the Pandas library, involve reducing large datasets into meaningful summaries to support Exploratory Data Analysis (EDA).
# Methods like df.describe(), df.sum(), df.min(), and df.count() compute descriptive statistics on the values within the DataFrame.
# Attributes such as df.columns, df.index, df.shape, df.info(), and df.nunique() provide essential metadata about the DataFrame's structure, dimensions, data types, and the number of unique entries it contains.

# %%
import pandas as pd

# %%
df_ext = pd.read_csv("data/nba.csv") # Load the dataset

print(type(df_ext)) # Check the type of the object
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_ext.columns # View the column names of the NBA DataFrame
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
df_ext.index # View the index of the NBA DataFrame
# Out:
# RangeIndex(start=0, stop=458, step=1)

# %%
df_ext.shape # Get the shape of the NBA DataFrame
# Out:
# (458, 9)

# %%
df_ext.count() # Count non-null entries for each column
# Out:
# Name        457
# Team        457
# Number      457
# Position    457
# Age         457
# Height      457
# Weight      457
# College     373
# Salary      446
# dtype: int64

# %%
df_ext.nunique() # Count unique values for each column
# Out:
# Name        457
# Team         30
# Number       53
# Position      5
# Age          22
# Height       18
# Weight       87
# College     118
# Salary      309
# dtype: int64

# %%
df_ext.info() # Get a concise summary of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df_ext.describe() # Get statistical summary of numerical columns
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %% [markdown]
# ## Aggregation Methods

# %%
df_ext.head() # View the first few rows of the DataFrame
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df_ext.sum() # Sum of each numerical column
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df_ext.sum() # Sum of each numerical column
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/pandas/core/frame.py:11697, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11688 @doc(make_doc("sum", ndim=2))
#   11689 def sum(
#   11690     self,
#    (...)
#   11695     **kwargs,
#   11696 ):
# > 11697     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11698     return result.__finalize__(self, method="sum")
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/pandas/core/generic.py:12571, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12563 def sum(
#   12564     self,
#   12565     axis: Axis | None = 0,
#    (...)
#   12569     **kwargs,
#   12570 ):
# > 12571     return self._min_count_stat_function(
#   12572         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12573     )
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/pandas/core/generic.py:12554, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12551 elif axis is lib.no_default:
#   12552     axis = 0
# > 12554 return self._reduce(
#   12555     func,
#   12556     name=name,
#   12557     axis=axis,
#   12558     skipna=skipna,
#   12559     numeric_only=numeric_only,
#   12560     min_count=min_count,
#   12561 )
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/pandas/core/frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/pandas/core/internals/managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/pandas/core/internals/blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/pandas/core/frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/pandas/core/nanops.py:85, in disallow.__call__.<locals>._f(*args, **kwargs)
#      81     raise TypeError(
#      82         f"reduction operation '{f_name}' not allowed for this dtype"
#      83     )
#      84 try:
# ---> 85     return f(*args, **kwargs)
#      86 except ValueError as e:
#      87     # we want to transform an object array
#      88     # ValueError message to the more typical TypeError
#      89     # e.g. this is normally a disallowed function on
#      90     # object arrays that contain strings
#      91     if is_object_dtype(args[0]):
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/pandas/core/nanops.py:477, in maybe_operate_rowwise.<locals>.newfunc(values, axis, **kwargs)
#     474         results = [func(x, **kwargs) for x in arrs]
#     475     return np.array(results)
# --> 477 return func(values, axis=axis, **kwargs)
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/pandas/core/nanops.py:646, in nansum(values, axis, skipna, min_count, mask)
#     643 elif dtype.kind == "m":
#     644     dtype_sum = np.dtype(np.float64)
# --> 646 the_sum = values.sum(axis, dtype=dtype_sum)
#     647 the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     649 return the_sum
#
# File ~/.conda/envs/p310env/lib/python3.10/site-packages/numpy/_core/_methods.py:52, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      50 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      51          initial=_NoValue, where=True):
# ---> 52     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "int") to str

# %%
df_ext.sum(numeric_only=True) # Sum of each numerical column (explicitly specifying numeric_only)
# Out:
# Number    8.079000e+03
# Age       1.231100e+04
# Weight    1.012360e+05
# Salary    2.159837e+09
# dtype: float64

# %%
df_ext.sum(axis=0,numeric_only=True) # Sum of each numerical column (specifying axis=0), column-wise
# Out:
# Number    8.079000e+03
# Age       1.231100e+04
# Weight    1.012360e+05
# Salary    2.159837e+09
# dtype: float64

# %%
df_ext.min(numeric_only=True) # Minimum value of each numerical column
# Out:
# Number        0.0
# Age          19.0
# Weight      161.0
# Salary    30888.0
# dtype: float64

# %%
df_ext['Salary'].max() # Maximum value of the 'Salary' column
# Out:
# np.float64(25000000.0)

# %%
df_ext.median(numeric_only=True) # Median of each numerical column
# Out:
# Number         13.0
# Age            26.0
# Weight        220.0
# Salary    2839073.0
# dtype: float64

# %%
df_ext['Salary'].mean() # Mean of the 'Salary' column
# Out:
# np.float64(4842684.105381166)

# %%
df_ext.value_counts() # Count unique rows in the DataFrame
# Out:
# Name              Team                    Number  Position  Age   Height  Weight  College          Salary
# Zach Randolph     Memphis Grizzlies       50.0    PF        34.0  6-9     260.0   Michigan State   9638555.0     1
# Aaron Brooks      Chicago Bulls           0.0     PG        31.0  6-0     161.0   Oregon           2250000.0     1
# Aaron Gordon      Orlando Magic           0.0     PF        20.0  6-9     220.0   Arizona          4171680.0     1
# Aaron Harrison    Charlotte Hornets       9.0     SG        21.0  6-6     210.0   Kentucky         525093.0      1
# Adreian Payne     Minnesota Timberwolves  33.0    PF        25.0  6-10    237.0   Michigan State   1938840.0     1
#                                                                                                                 ..
# Andre Roberson    Oklahoma City Thunder   21.0    SG        24.0  6-7     210.0   Colorado         1210800.0     1
# Andrew Bogut      Golden State Warriors   12.0    C         31.0  7-0     260.0   Utah             13800000.0    1
# Andrew Goudelock  Houston Rockets         0.0     PG        27.0  6-3     200.0   Charleston       200600.0      1
# Andrew Nicholson  Orlando Magic           44.0    PF        26.0  6-9     250.0   St. Bonaventure  2380593.0     1
# Andrew Wiggins    Minnesota Timberwolves  22.0    SG        21.0  6-8     199.0   Kansas           5758680.0     1
# Name: count, Length: 364, dtype: int64

# %%
df_ext['Team'].value_counts() # Count unique values in the 'Team' column
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Boston Celtics            15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Phoenix Suns              15
# Sacramento Kings          15
# Chicago Bulls             15
# Philadelphia 76ers        15
# Toronto Raptors           15
# Golden State Warriors     15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Dallas Mavericks          15
# Houston Rockets           15
# San Antonio Spurs         15
# Atlanta Hawks             15
# Charlotte Hornets         15
# Miami Heat                15
# Washington Wizards        15
# Denver Nuggets            15
# Oklahoma City Thunder     15
# Utah Jazz                 15
# Portland Trail Blazers    15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %% [markdown]
# Next Chapter [Indexing and Selection](3.IndexingSelection.ipynb)
